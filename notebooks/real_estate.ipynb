# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("D:\Guvi Projects\Luxury Housing Sales Analysis\dataset\cleaned_real_estate_data.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\GOKULRAJ VIJAYAKUMAR\AppData\Local\Temp\ipykernel_2268\414581927.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("D:\Guvi Projects\Luxury Housing Sales Analysis\dataset\cleaned_real_estate_data.csv")
#   Property_ID       Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 0  PROP000001      sarjapur road    Project_0            rmz            4025
# 1  PROP000002        indiranagar    Project_1    puravankara            5760
# 2  PROP000003  bannerghatta road    Project_2   tata housing            7707
# 3  PROP000004       bellary road    Project_3        embassy            6192
# 4  PROP000005        koramangala    Project_4        snn raj            7147
#
#    Ticket_Price_Cr Transaction_Type      Buyer_Type Purchase_Quarter  \
# 0        12.750846          primary             nri       31-03-2025
# 1        16.292152          primary           other       30-06-2024
# 2        10.517724          primary  high net worth       31-12-2023
# 3         9.396367          primary  high net worth       31-03-2024
# 4        15.345392        secondary  high net worth       31-12-2024
#
#    Connectivity_Score  ...   Possession_Status Sales_Channel NRI_Buyer  \
# 0            7.990091  ...              launch        broker       yes
# 1            4.839024  ...  under construction      nri desk        no
# 2            8.131315  ...       ready to move        direct       yes
# 3            7.501657  ...       ready to move        online       yes
# 4            4.525216  ...  under construction        broker        no
#
#   Locality_Infra_Score  Avg_Traffic_Time_Min  Quarter_Number  BHK  \
# 0             9.212491                    18               1    4
# 1             7.723898                   106               2    3
# 2             6.985493                   113               4    4
# 3             6.100929                   106               1    3
# 4             5.312510                    18               4    4
#
#    Price_per_Sqft  Booking_Flag  Booking_Status
# 0     31679.12059             1          Booked
# 1     28284.98589             1          Booked
# 2     13646.97601             1          Booked
# 3     15175.01210             1          Booked
# 4     21471.09619             0      Not Booked
#
# [5 rows x 21 columns]

# %%
print(df.shape)
# Out:
# (45649, 21)

# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()

user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
db = os.getenv("DB_NAME")

engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{db}")

# %%
conn = engine.connect()
print("Connected!")
conn.close()
# Out:
# Connected!

# %%
df.to_sql('real_estate_data', con=engine, if_exists='replace', index=False)
# Out:
# 45649

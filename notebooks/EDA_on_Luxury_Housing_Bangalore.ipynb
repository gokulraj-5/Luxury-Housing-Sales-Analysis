# %%
import pandas as pd

# %%
df=pd.read_csv('Luxury_Housing_Bangalore.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       57424 non-null  object
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  object
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
#  14  NRI_Buyer             63716 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# Micro_Market                0
# Project_Name                0
# Developer_Name              0
# Unit_Size_Sqft           6354
# Configuration               0
# Ticket_Price_Cr          6293
# Transaction_Type            0
# Buyer_Type                  0
# Purchase_Quarter            0
# Connectivity_Score          0
# Amenity_Score            6293
# Possession_Status           1
# Sales_Channel               1
# NRI_Buyer                   1
# Locality_Infra_Score        1
# Avg_Traffic_Time_Min        1
# Buyer_Comments          11635
# dtype: int64

# %%
df['Developer_Name'] = df['Developer_Name'].str.lower()

# %%
df.head()
# Out:
#   Property_ID       Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 0  PROP000001      Sarjapur Road    Project_0            rmz          4025.0
# 1  PROP000002        Indiranagar    Project_1    puravankara          5760.0
# 2  PROP000003  Bannerghatta Road    Project_2   tata housing          7707.0
# 3  PROP000004       bellary road    Project_3        embassy          6192.0
# 4  PROP000005        Koramangala    Project_4        snn raj          7147.0
#
#   Configuration     Ticket_Price_Cr Transaction_Type Buyer_Type  \
# 0          4bhk  12.750846039118798          Primary        NRI
# 1          3Bhk  16.292151871065954          Primary      Other
# 2          4bhk  10.517724412961911          Primary        HNI
# 3          3BHK   9.396367494232896          Primary        HNI
# 4          4Bhk  15.345392444511946        Secondary        HNI
#
#   Purchase_Quarter  Connectivity_Score  Amenity_Score   Possession_Status  \
# ...

# %%
df['Developer_Name'] = df['Developer_Name'].str.strip()

# %%
df['Developer_Name'] = df['Developer_Name'].str.replace(r'[^\w\s]', '', regex=True)

# %%
df.head()
# Out:
#   Property_ID       Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 0  PROP000001      Sarjapur Road    Project_0            rmz          4025.0
# 1  PROP000002        Indiranagar    Project_1    puravankara          5760.0
# 2  PROP000003  Bannerghatta Road    Project_2   tata housing          7707.0
# 3  PROP000004       bellary road    Project_3        embassy          6192.0
# 4  PROP000005        Koramangala    Project_4        snn raj          7147.0
#
#   Configuration     Ticket_Price_Cr Transaction_Type Buyer_Type  \
# 0          4bhk  12.750846039118798          Primary        NRI
# 1          3Bhk  16.292151871065954          Primary      Other
# 2          4bhk  10.517724412961911          Primary        HNI
# 3          3BHK   9.396367494232896          Primary        HNI
# 4          4Bhk  15.345392444511946        Secondary        HNI
#
#   Purchase_Quarter  Connectivity_Score  Amenity_Score   Possession_Status  \
# ...

# %%
df['Configuration'] = df['Configuration'].str.lower().str.strip()

# %%
df['Configuration'] = df['Configuration'].str.replace(r'\s+', '', regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       57424 non-null  object
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  object
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
#  14  NRI_Buyer             63716 non-null  object
# ...

# %%
df['Ticket_Price_Cr'] = pd.to_numeric(df['Ticket_Price_Cr'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  object
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df = df.drop(columns=['Buyer_Comments'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  object
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df['Purchase_Quarter']
# Out:
# 0        2025-03-31
# 1        2024-06-30
# 2        2023-12-31
# 3        2024-03-31
# 4        2024-12-31
#             ...
# 63712    2024-09-30
# 63713    2024-03-31
# 63714    2025-03-31
# 63715    2023-09-30
# 63716    2023-12-31
# Name: Purchase_Quarter, Length: 63717, dtype: object

# %%
df['Purchase_Quarter'] = pd.to_datetime(df['Purchase_Quarter'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  datetime64[ns]
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df['Quarter_Number'] = df['Purchase_Quarter'].dt.quarter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  datetime64[ns]
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df.Quarter_Number
# Out:
# 0        1
# 1        2
# 2        4
# 3        1
# 4        4
#         ..
# 63712    3
# 63713    1
# 63714    1
# 63715    3
# 63716    4
# Name: Quarter_Number, Length: 63717, dtype: int32

# %%
df['Ticket_Price_Cr'] = pd.to_numeric(df['Ticket_Price_Cr'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        57363 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  datetime64[ns]
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# Micro_Market                0
# Project_Name                0
# Developer_Name              0
# Unit_Size_Sqft           6354
# Configuration               0
# Ticket_Price_Cr         17831
# Transaction_Type            0
# Buyer_Type                  0
# Purchase_Quarter            0
# Connectivity_Score          0
# Amenity_Score            6293
# Possession_Status           1
# Sales_Channel               1
# NRI_Buyer                   1
# Locality_Infra_Score        1
# Avg_Traffic_Time_Min        1
# Quarter_Number              0
# dtype: int64

# %%
df['Unit_Size_Sqft'] = df.groupby(['Configuration'])['Unit_Size_Sqft']\
    .transform(lambda x: x.fillna(x.median()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        63717 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  datetime64[ns]
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df['Configuration'].value_counts()
# Out:
# Configuration
# 5bhk+    21374
# 3bhk     21262
# 4bhk     21081
# Name: count, dtype: int64

# %%
df['BHK'] = df['Configuration'].str.extract(r'(\d+)').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        63717 non-null  float64
#  5   Configuration         63717 non-null  object
#  6   Ticket_Price_Cr       45886 non-null  float64
#  7   Transaction_Type      63717 non-null  object
#  8   Buyer_Type            63717 non-null  object
#  9   Purchase_Quarter      63717 non-null  datetime64[ns]
#  10  Connectivity_Score    63717 non-null  float64
#  11  Amenity_Score         57424 non-null  float64
#  12  Possession_Status     63716 non-null  object
#  13  Sales_Channel         63716 non-null  object
# ...

# %%
df.BHK
# Out:
# 0        4
# 1        3
# 2        4
# 3        3
# 4        4
#         ..
# 63712    5
# 63713    3
# 63714    5
# 63715    3
# 63716    5
# Name: BHK, Length: 63717, dtype: int64

# %%
df = df.drop(columns=['Configuration'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        63717 non-null  float64
#  5   Ticket_Price_Cr       45886 non-null  float64
#  6   Transaction_Type      63717 non-null  object
#  7   Buyer_Type            63717 non-null  object
#  8   Purchase_Quarter      63717 non-null  datetime64[ns]
#  9   Connectivity_Score    63717 non-null  float64
#  10  Amenity_Score         57424 non-null  float64
#  11  Possession_Status     63716 non-null  object
#  12  Sales_Channel         63716 non-null  object
#  13  NRI_Buyer             63716 non-null  object
# ...

# %%
df.Amenity_Score
# Out:
# 0        5.462863
# 1             NaN
# 2        8.669227
# 3        5.720246
# 4        8.609649
#            ...
# 63712    5.664818
# 63713    5.625323
# 63714    5.355570
# 63715    7.446287
# 63716         NaN
# Name: Amenity_Score, Length: 63717, dtype: float64

# %%
df['Amenity_Score'].describe()
# Out:
# count    57424.000000
# mean         7.509119
# std          1.440236
# min          5.000265
# 25%          6.267943
# 50%          7.508014
# 75%          8.757439
# max          9.999659
# Name: Amenity_Score, dtype: float64

# %%
df['Amenity_Score'] = df.groupby('Micro_Market')['Amenity_Score']\
    .transform(lambda x: x.fillna(x.median()))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63717 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           63717 non-null  object
#  1   Micro_Market          63717 non-null  object
#  2   Project_Name          63717 non-null  object
#  3   Developer_Name        63717 non-null  object
#  4   Unit_Size_Sqft        63717 non-null  float64
#  5   Ticket_Price_Cr       45886 non-null  float64
#  6   Transaction_Type      63717 non-null  object
#  7   Buyer_Type            63717 non-null  object
#  8   Purchase_Quarter      63717 non-null  datetime64[ns]
#  9   Connectivity_Score    63717 non-null  float64
#  10  Amenity_Score         63717 non-null  float64
#  11  Possession_Status     63716 non-null  object
#  12  Sales_Channel         63716 non-null  object
#  13  NRI_Buyer             63716 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# Micro_Market                0
# Project_Name                0
# Developer_Name              0
# Unit_Size_Sqft              0
# Ticket_Price_Cr         17831
# Transaction_Type            0
# Buyer_Type                  0
# Purchase_Quarter            0
# Connectivity_Score          0
# Amenity_Score               0
# Possession_Status           1
# Sales_Channel               1
# NRI_Buyer                   1
# Locality_Infra_Score        1
# Avg_Traffic_Time_Min        1
# Quarter_Number              0
# BHK                         0
# dtype: int64

# %%
df = df.dropna(subset=['Ticket_Price_Cr', 'Unit_Size_Sqft'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45886 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45886 non-null  object
#  1   Micro_Market          45886 non-null  object
#  2   Project_Name          45886 non-null  object
#  3   Developer_Name        45886 non-null  object
#  4   Unit_Size_Sqft        45886 non-null  float64
#  5   Ticket_Price_Cr       45886 non-null  float64
#  6   Transaction_Type      45886 non-null  object
#  7   Buyer_Type            45886 non-null  object
#  8   Purchase_Quarter      45886 non-null  datetime64[ns]
#  9   Connectivity_Score    45886 non-null  float64
#  10  Amenity_Score         45886 non-null  float64
#  11  Possession_Status     45885 non-null  object
#  12  Sales_Channel         45885 non-null  object
#  13  NRI_Buyer             45885 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID             0
# Micro_Market            0
# Project_Name            0
# Developer_Name          0
# Unit_Size_Sqft          0
# Ticket_Price_Cr         0
# Transaction_Type        0
# Buyer_Type              0
# Purchase_Quarter        0
# Connectivity_Score      0
# Amenity_Score           0
# Possession_Status       1
# Sales_Channel           1
# NRI_Buyer               1
# Locality_Infra_Score    1
# Avg_Traffic_Time_Min    1
# Quarter_Number          0
# BHK                     0
# dtype: int64

# %%
df['Possession_Status'].fillna(df['Possession_Status'].mode()[0], inplace=True)
df['Sales_Channel'].fillna(df['Sales_Channel'].mode()[0], inplace=True)
df['NRI_Buyer'].fillna(df['NRI_Buyer'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_6259/1390507731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Possession_Status'].fillna(df['Possession_Status'].mode()[0], inplace=True)
# /tmp/ipykernel_6259/1390507731.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['Locality_Infra_Score'].fillna(df['Locality_Infra_Score'].median(), inplace=True)
df['Avg_Traffic_Time_Min'].fillna(df['Avg_Traffic_Time_Min'].median(), inplace=True)
# Out:
# /tmp/ipykernel_6259/3991512247.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Locality_Infra_Score'].fillna(df['Locality_Infra_Score'].median(), inplace=True)
# /tmp/ipykernel_6259/3991512247.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45886 entries, 0 to 63716
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45886 non-null  object
#  1   Micro_Market          45886 non-null  object
#  2   Project_Name          45886 non-null  object
#  3   Developer_Name        45886 non-null  object
#  4   Unit_Size_Sqft        45886 non-null  float64
#  5   Ticket_Price_Cr       45886 non-null  float64
#  6   Transaction_Type      45886 non-null  object
#  7   Buyer_Type            45886 non-null  object
#  8   Purchase_Quarter      45886 non-null  datetime64[ns]
#  9   Connectivity_Score    45886 non-null  float64
#  10  Amenity_Score         45886 non-null  float64
#  11  Possession_Status     45886 non-null  object
#  12  Sales_Channel         45886 non-null  object
#  13  NRI_Buyer             45886 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID             0
# Micro_Market            0
# Project_Name            0
# Developer_Name          0
# Unit_Size_Sqft          0
# Ticket_Price_Cr         0
# Transaction_Type        0
# Buyer_Type              0
# Purchase_Quarter        0
# Connectivity_Score      0
# Amenity_Score           0
# Possession_Status       0
# Sales_Channel           0
# NRI_Buyer               0
# Locality_Infra_Score    0
# Avg_Traffic_Time_Min    0
# Quarter_Number          0
# BHK                     0
# dtype: int64

# %%
df[['Ticket_Price_Cr', 'Unit_Size_Sqft']].isnull().sum()
# Out:
# Ticket_Price_Cr    0
# Unit_Size_Sqft     0
# dtype: int64

# %%
df['Price_per_Sqft'] = (df['Ticket_Price_Cr'] * 1e7) / df['Unit_Size_Sqft']

# %%
df['Price_per_Sqft'].describe()
# Out:
# count    4.588600e+04
# mean    -6.151959e+05
# std      1.029587e+07
# min     -1.000000e+09
# 25%      1.547785e+04
# 50%      2.000823e+04
# 75%      2.666160e+04
# max      3.207184e+05
# Name: Price_per_Sqft, dtype: float64

# %%
df[df['Ticket_Price_Cr'] <= 0]
# Out:
#       Property_ID Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 3645   PROP003646  INDIRANAGAR  Project_145        embassy          5092.0
# 39358  PROP039359       Hebbal  Project_358   tata housing          4924.0
# 50185  PROP050186     jp nagar  Project_185         godrej          5807.0
#
#        Ticket_Price_Cr Transaction_Type       Buyer_Type Purchase_Quarter  \
# 3645         -0.391623          Primary  Startup Founder       2024-06-30
# 39358        -0.287197          Primary              NRI       2023-09-30
# 50185        -0.193873          Primary              CXO       2024-12-31
#
#        Connectivity_Score  Amenity_Score   Possession_Status Sales_Channel  \
# 3645             7.149634       6.123946  Under construction        Direct
# 39358            4.167448       7.430698       Ready to move      NRI Desk
# 50185            5.707500       9.986799              Launch        Broker
#
# ...

# %%
df = df[df['Ticket_Price_Cr'] > 0]

# %%
df['Price_per_Sqft'] = (df['Ticket_Price_Cr'] * 1e7) / df['Unit_Size_Sqft']

# %%
df['Price_per_Sqft'].describe()
# Out:
# count    4.588300e+04
# mean    -6.152361e+05
# std      1.029621e+07
# min     -1.000000e+09
# 25%      1.547825e+04
# 50%      2.000867e+04
# 75%      2.666200e+04
# max      3.207184e+05
# Name: Price_per_Sqft, dtype: float64

# %%
df[df['Ticket_Price_Cr'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Property_ID, Micro_Market, Project_Name, Developer_Name, Unit_Size_Sqft, Ticket_Price_Cr, Transaction_Type, Buyer_Type, Purchase_Quarter, Connectivity_Score, Amenity_Score, Possession_Status, Sales_Channel, NRI_Buyer, Locality_Infra_Score, Avg_Traffic_Time_Min, Quarter_Number, BHK, Price_per_Sqft]
# Index: []

# %%
df[df['Price_per_Sqft'] < 0]
# Out:
#       Property_ID   Micro_Market Project_Name     Developer_Name  \
# 145    PROP000146   bellary road  Project_145        puravankara
# 238    PROP000239    KORAMANGALA  Project_238              sobha
# 244    PROP000245  sarjapur road  Project_244          lt realty
# 289    PROP000290      Yelahanka  Project_289              sobha
# 747    PROP000748  sarjapur road  Project_247            embassy
# ...           ...            ...          ...                ...
# 62514  PROP062515     WHITEFIELD   Project_14            embassy
# 62599  PROP062600  SARJAPUR ROAD   Project_99  total environment
# 63016  PROP063017    hennur road   Project_16       tata housing
# 63084  PROP063085    rajajinagar   Project_84            snn raj
# 63514  PROP063515        Mg Road   Project_14              sobha
#
#        Unit_Size_Sqft  Ticket_Price_Cr Transaction_Type       Buyer_Type  \
# 145              -1.0         9.094891        Secondary  Startup Founder
# ...

# %%
df['Unit_Size_Sqft'].describe()
# Out:
# count    45883.000000
# mean      5974.458710
# std       1690.294923
# min         -1.000000
# 25%       4660.000000
# 50%       5986.000000
# 75%       7327.000000
# max       8999.000000
# Name: Unit_Size_Sqft, dtype: float64

# %%
import numpy as np
df['Unit_Size_Sqft'] = df['Unit_Size_Sqft'].replace(-1, np.nan)

# %%
df = df.dropna(subset=['Unit_Size_Sqft'])

# %%
df['Price_per_Sqft'] = (df['Ticket_Price_Cr'] * 1e7) / df['Unit_Size_Sqft']

# %%
df['Price_per_Sqft'].describe()
# Out:
# count     45649.000000
# mean      23096.865702
# std       16195.861583
# min        1181.384845
# 25%       15553.025813
# 50%       20060.907786
# 75%       26718.813779
# max      320718.409237
# Name: Price_per_Sqft, dtype: float64

# %%
df.corr(numeric_only=True)['Price_per_Sqft'].sort_values(ascending=False)
# Out:
# Price_per_Sqft          1.000000
# Ticket_Price_Cr         0.858664
# Quarter_Number          0.005848
# BHK                     0.004972
# Amenity_Score           0.002056
# Avg_Traffic_Time_Min   -0.001184
# Locality_Infra_Score   -0.002477
# Connectivity_Score     -0.006034
# Unit_Size_Sqft         -0.419512
# Name: Price_per_Sqft, dtype: float64

# %%
df['Transaction_Type'].value_counts()
# Out:
# Transaction_Type
# Secondary    22857
# Primary      22792
# Name: count, dtype: int64

# %%
df['Booking_Flag'] = df['Transaction_Type'].map({
    'Primary': 1,
    'Secondary': 0
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
df.groupby('Booking_Flag')['Price_per_Sqft'].mean()
# Out:
# Booking_Flag
# 0    23014.524253
# 1    23179.441980
# Name: Price_per_Sqft, dtype: float64

# %%
df['Developer_Name'].unique()
# Out:
# array(['rmz', 'puravankara', 'tata housing', 'embassy', 'snn raj',
#        'prestige', 'total environment', 'godrej', 'brigade', 'lt realty',
#        'sobha'], dtype=object)

# %%
df['Developer_Name'].nunique()
# Out:
# 11

# %%
df['Developer_Name'].value_counts()
# Out:
# Developer_Name
# prestige             4238
# snn raj              4222
# lt realty            4199
# puravankara          4172
# godrej               4163
# total environment    4158
# brigade              4128
# embassy              4107
# rmz                  4105
# sobha                4083
# tata housing         4074
# Name: count, dtype: int64

# %%
df['Micro_Market'].unique()
# Out:
# array(['Sarjapur Road', 'Indiranagar', 'Bannerghatta Road',
#        'bellary road', 'Koramangala', 'whitefield', 'sarjapur road',
#        'JP NAGAR', 'Rajajinagar', 'koramangala', 'YELAHANKA',
#        'WHITEFIELD', 'indiranagar', 'jayanagar', 'DOMLUR', 'HENNUR ROAD',
#        'Domlur', 'Electronic City', 'Mg Road', 'Hebbal', 'mg road',
#        'jp nagar', 'Jayanagar', 'BANNERGHATTA ROAD', 'MG ROAD',
#        'KANAKAPURA ROAD', 'BELLARY ROAD', 'ELECTRONIC CITY',
#        'Bellary Road', 'Hennur Road', 'rajajinagar', 'electronic city',
#        'Kanakapura Road', 'INDIRANAGAR', 'hennur road', 'kanakapura road',
#        'bannerghatta road', 'HEBBAL', 'domlur', 'Whitefield', 'yelahanka',
#        'Yelahanka', 'hebbal', 'RAJAJINAGAR', 'SARJAPUR ROAD',
#        'KORAMANGALA', 'Jp Nagar', 'JAYANAGAR'], dtype=object)

# %%
df['Micro_Market'].value_counts()
# Out:
# Micro_Market
# mg road              995
# Bannerghatta Road    992
# Electronic City      991
# electronic city      983
# Jp Nagar             983
# WHITEFIELD           982
# jayanagar            981
# JAYANAGAR            980
# BANNERGHATTA ROAD    979
# indiranagar          979
# bannerghatta road    978
# bellary road         976
# jp nagar             974
# sarjapur road        967
# BELLARY ROAD         966
# Kanakapura Road      965
# ELECTRONIC CITY      965
# JP NAGAR             961
# Bellary Road         960
# Sarjapur Road        958
# Jayanagar            956
# SARJAPUR ROAD        956
# Hebbal               952
# HEBBAL               951
# KORAMANGALA          950
# hebbal               948
# MG ROAD              946
# Yelahanka            945
# yelahanka            944
# kanakapura road      944
# domlur               943
# hennur road          942
# whitefield           940
# Hennur Road          933
# rajajinagar          933
# RAJAJINAGAR          933
# ...

# %%
df['Micro_Market'] = (
    df['Micro_Market']
    .str.lower()
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
)

# %%
df['Micro_Market'] = df['Micro_Market'].str.replace(r'[^\w\s]', '', regex=True)

# %%
df['Micro_Market'] = df['Micro_Market'].replace({
    'rd': 'road',
    'st': 'street',
    'nagar': 'nagar',
    'layout': 'layout'
}, regex=True)

# %%
df['Micro_Market'].value_counts().head(20)
# Out:
# Micro_Market
# bannerghatta road    2949
# electronic city      2939
# jp nagar             2918
# jayanagar            2917
# bellary road         2902
# sarjapur road        2881
# mg road              2866
# whitefield           2854
# hebbal               2851
# indiranagar          2829
# kanakapura road      2813
# koramangala          2799
# hennur road          2797
# rajajinagar          2790
# yelahanka            2780
# domlur               2764
# Name: count, dtype: int64

# %%
df['Micro_Market'].value_counts()
# Out:
# Micro_Market
# bannerghatta road    2949
# electronic city      2939
# jp nagar             2918
# jayanagar            2917
# bellary road         2902
# sarjapur road        2881
# mg road              2866
# whitefield           2854
# hebbal               2851
# indiranagar          2829
# kanakapura road      2813
# koramangala          2799
# hennur road          2797
# rajajinagar          2790
# yelahanka            2780
# domlur               2764
# Name: count, dtype: int64

# %%
df['Buyer_Type'].value_counts()
# Out:
# Buyer_Type
# CXO                9211
# NRI                9184
# Other              9180
# Startup Founder    9147
# HNI                8927
# Name: count, dtype: int64

# %%
df['Buyer_Type'] = (
    df['Buyer_Type']
    .str.lower()
    .str.strip()
)

# %%
df['Buyer_Type'] = df['Buyer_Type'].replace({
    'cxo': 'executive',
    'hni': 'high net worth',
    'startup founder': 'entrepreneur'
})

# %%
df.groupby('Buyer_Type')['Price_per_Sqft'].mean().sort_values()
# Out:
# Buyer_Type
# executive         23018.844555
# nri               23050.762483
# high net worth    23059.250250
# other             23177.121165
# entrepreneur      23177.888197
# Name: Price_per_Sqft, dtype: float64

# %%
df['Buyer_Type'].value_counts()
# Out:
# Buyer_Type
# executive         9211
# nri               9184
# other             9180
# entrepreneur      9147
# high net worth    8927
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
df['Booking_Status'] = df['Transaction_Type'].apply(
    lambda x: 'Booked' if x == 'Primary' else 'Not Booked'
)

# %%
df['Booking_Status'].value_counts()
# Out:
# Booking_Status
# Not Booked    22857
# Booked        22792
# Name: count, dtype: int64

# %%
booked_count = df[df['Booking_Status'] == 'Booked'].shape[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
booking_count = len(df)

# %%
booking_conversion_rate = booked_count / booking_count

# %%
print("Total:", booking_count)
print("Booked:", booked_count)
print("Conversion Rate:", booking_conversion_rate)
# Out:
# Total: 45649
# Booked: 22792
# Conversion Rate: 0.49928804574032287

# %%
conversion_by_market = df.groupby('Micro_Market').apply(
    lambda x: (x['Booking_Status'] == 'Booked').mean()
).reset_index(name='Booking_Conversion_Rate')
# Out:
# /tmp/ipykernel_6259/3869310969.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   conversion_by_market = df.groupby('Micro_Market').apply(

# %%
trend = df.groupby(['Purchase_Quarter', 'Micro_Market']).size().reset_index(name='Booking_Count')

# %%
builder_perf = df.groupby('Developer_Name').agg({
    'Ticket_Price_Cr': ['sum', 'mean']
}).reset_index()

builder_perf.columns = ['Developer_Name', 'Total_Revenue', 'Avg_Ticket']

# %%
sales_channel = df.groupby(['Sales_Channel', 'Booking_Status']).size().unstack(fill_value=0)

# %%
config_demand = df['BHK'].value_counts().reset_index()
config_demand.columns = ['BHK', 'Booking_Count']

# %%
df.isnull().sum()
# Out:
# Property_ID             0
# Micro_Market            0
# Project_Name            0
# Developer_Name          0
# Unit_Size_Sqft          0
# Ticket_Price_Cr         0
# Transaction_Type        0
# Buyer_Type              0
# Purchase_Quarter        0
# Connectivity_Score      0
# Amenity_Score           0
# Possession_Status       0
# Sales_Channel           0
# NRI_Buyer               0
# Locality_Infra_Score    0
# Avg_Traffic_Time_Min    0
# Quarter_Number          0
# BHK                     0
# Price_per_Sqft          0
# Booking_Flag            0
# Booking_Status          0
# dtype: int64

# %%
df[df['Ticket_Price_Cr'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Property_ID, Micro_Market, Project_Name, Developer_Name, Unit_Size_Sqft, Ticket_Price_Cr, Transaction_Type, Buyer_Type, Purchase_Quarter, Connectivity_Score, Amenity_Score, Possession_Status, Sales_Channel, NRI_Buyer, Locality_Infra_Score, Avg_Traffic_Time_Min, Quarter_Number, BHK, Price_per_Sqft, Booking_Flag, Booking_Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[df['Unit_Size_Sqft'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Property_ID, Micro_Market, Project_Name, Developer_Name, Unit_Size_Sqft, Ticket_Price_Cr, Transaction_Type, Buyer_Type, Purchase_Quarter, Connectivity_Score, Amenity_Score, Possession_Status, Sales_Channel, NRI_Buyer, Locality_Infra_Score, Avg_Traffic_Time_Min, Quarter_Number, BHK, Price_per_Sqft, Booking_Flag, Booking_Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[df['Price_per_Sqft'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Property_ID, Micro_Market, Project_Name, Developer_Name, Unit_Size_Sqft, Ticket_Price_Cr, Transaction_Type, Buyer_Type, Purchase_Quarter, Connectivity_Score, Amenity_Score, Possession_Status, Sales_Channel, NRI_Buyer, Locality_Infra_Score, Avg_Traffic_Time_Min, Quarter_Number, BHK, Price_per_Sqft, Booking_Flag, Booking_Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[['Ticket_Price_Cr', 'Unit_Size_Sqft', 'Price_per_Sqft']].describe()
# Out:
#        Ticket_Price_Cr  Unit_Size_Sqft  Price_per_Sqft
# count     45649.000000    45649.000000    45649.000000
# mean         12.756004     6005.089334    23096.865702
# std           7.767527     1639.441562    16195.861583
# min           0.776524     3000.000000     1181.384845
# 25%          10.025175     4687.000000    15553.025813
# 50%          12.053247     5986.000000    20060.907786
# 75%          14.105617     7334.000000    26718.813779
# max         100.000000     8999.000000   320718.409237

# %%
Q1 = df['Price_per_Sqft'].quantile(0.25)
Q3 = df['Price_per_Sqft'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -1195.656136826734 43467.49572875105

# %%
outliers = df[(df['Price_per_Sqft'] < lower_bound) | (df['Price_per_Sqft'] > upper_bound)]

print("Outliers count:", len(outliers))
# Out:
# Outliers count: 1659

# %%
df['Price_per_Sqft'] = df['Price_per_Sqft'].clip(upper=upper_bound)

# %%
df['Price_per_Sqft'].describe()
# Out:
# count    45649.000000
# mean     21893.478045
# std       8707.913885
# min       1181.384845
# 25%      15553.025813
# 50%      20060.907786
# 75%      26718.813779
# max      43467.495729
# Name: Price_per_Sqft, dtype: float64

# %%
df[df['Price_per_Sqft'] > upper_bound]['Micro_Market'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum() == 0 and (df[['Ticket_Price_Cr','Unit_Size_Sqft','Price_per_Sqft']] > 0).all().all() and df.duplicated().sum() == 0
# Out:
# np.True_

# %%
df['Price_per_Sqft'] = (df['Ticket_Price_Cr'] * 1e7) / df['Unit_Size_Sqft']

# %%
df['Price_per_Sqft'].describe()
# Out:
# count     45649.000000
# mean      23096.865702
# std       16195.861583
# min        1181.384845
# 25%       15553.025813
# 50%       20060.907786
# 75%       26718.813779
# max      320718.409237
# Name: Price_per_Sqft, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
for col in df.select_dtypes(include='object'):
    print(f"\n🔹 {col}")
    print(df[col].unique())
# Out:
# 🔹 Property_ID
# ['PROP000001' 'PROP000002' 'PROP000003' ... 'PROP063715' 'PROP063716'
#  'PROP063717']
#
# 🔹 Micro_Market
# ['sarjapur road' 'indiranagar' 'bannerghatta road' 'bellary road'
#  'koramangala' 'whitefield' 'jp nagar' 'rajajinagar' 'yelahanka'
#  'jayanagar' 'domlur' 'hennur road' 'electronic city' 'mg road' 'hebbal'
#  'kanakapura road']
#
# 🔹 Project_Name
# ['Project_0' 'Project_1' 'Project_2' 'Project_3' 'Project_4' 'Project_6'
#  'Project_7' 'Project_8' 'Project_9' 'Project_10' 'Project_11'
#  'Project_12' 'Project_13' 'Project_14' 'Project_15' 'Project_16'
#  'Project_17' 'Project_18' 'Project_19' 'Project_20' 'Project_22'
#  'Project_25' 'Project_27' 'Project_28' 'Project_29' 'Project_30'
#  'Project_31' 'Project_32' 'Project_33' 'Project_34' 'Project_35'
#  'Project_36' 'Project_37' 'Project_41' 'Project_42' 'Project_44'
#  'Project_45' 'Project_46' 'Project_47' 'Project_49' 'Project_50'
#  'Project_52' 'Project_54' 'Project_55' 'Project_56' 'Project_57'
# ...

# %%
df['Transaction_Type'] = df['Transaction_Type'].str.lower()

# %%
df['Possession_Status'] = df['Possession_Status'].str.lower()

# %%
df['Sales_Channel'] = df['Sales_Channel'].str.lower()

# %%
df.to_csv("cleaned_real_estate_data.csv", index=False, encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
df=df.drop(columns=['Price_per_Sqft_Log'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45649 entries, 0 to 63716
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Property_ID           45649 non-null  object
#  1   Micro_Market          45649 non-null  object
#  2   Project_Name          45649 non-null  object
#  3   Developer_Name        45649 non-null  object
#  4   Unit_Size_Sqft        45649 non-null  float64
#  5   Ticket_Price_Cr       45649 non-null  float64
#  6   Transaction_Type      45649 non-null  object
#  7   Buyer_Type            45649 non-null  object
#  8   Purchase_Quarter      45649 non-null  datetime64[ns]
#  9   Connectivity_Score    45649 non-null  float64
#  10  Amenity_Score         45649 non-null  float64
#  11  Possession_Status     45649 non-null  object
#  12  Sales_Channel         45649 non-null  object
#  13  NRI_Buyer             45649 non-null  object
# ...

# %%
df.to_csv("cleaned_real_estate_data.csv", index=False, encoding='utf-8')
